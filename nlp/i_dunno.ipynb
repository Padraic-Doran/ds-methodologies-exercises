# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
from requests import get

# %%
urls = ['https://github.com/search?o=desc&p=1&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=2&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=3&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=4&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=5&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=6&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=7&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=8&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=9&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=10&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=11&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=12&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=13&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=14&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=15&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=16&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=17&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=18&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=19&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=20&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=21&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=22&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=23&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=24&q=stars%3A%3E1&s=forks&type=Repositories',
       'https://github.com/search?o=desc&p=25&q=stars%3A%3E1&s=forks&type=Repositories']

# %%
def get_urls(start, finish):
    pages = list(range(start,finish+1))
    page_urls = []
    for page in pages:
        p = f'https://github.com/search?o=desc&p={page}&q=stars%3A%3E1&s=forks&type=Repositories'
        page_urls.append(p)

    repo_links_all = []
    for page in page_urls:
        url = page
        headers  = {'User-Agent' : 'Codeup Data Science Student'} #user-agent to decrease chance of being rejected by github
        response = get(url,headers)
        soup = BeautifulSoup(response.text) #created a BS object
        repo_list = soup.find('ul', class_='repo-list') #find section of text of interest
        links = repo_list.find_all(href = True) #isolate the 'href's 
        repo_links= [link['href'] for link in links if not re.match(r'^/topics',link['href']) and not re.match(r'^https',link['href'])\
                 and link['href'].count('/') < 3] #further pare down list by excluding anything that begins with /topics, https or more than 2 forward slashes
        repo_links_all.extend(repo_links)
    return repo_links_all

# %%
repos = ['jtleek/datasharing',
 'rdpeng/ProgrammingAssignment2',
 'octocat/Spoon-Knife',
 'tensorflow/tensorflow',
 'twbs/bootstrap',
 'SmartThingsCommunity/SmartThingsPublic',
 'rdpeng/ExData_Plotting1',
 'github/gitignore',
 'tensorflow/models',
 'nightscout/cgm-remote-monitor',
 'EbookFoundation/free-programming-books',
 'rdpeng/RepData_PeerAssessment1',
 'opencv/opencv',
 'torvalds/linux',
 'angular/angular.js',
 'eugenp/tutorials',
 'DataScienceSpecialization/courses',
 'jackfrued/Python-100-Days',
 'spring-projects/spring-boot',
 'jwasham/coding-interview-university',
 'CyC2018/CS-Notes',
 'facebook/react',
 'barryclark/jekyll-now',
 'jlord/patchwork',
 'Pierian-Data/Complete-Python-3-Bootcamp',
 'bitcoin/bitcoin',
 'udacity/frontend-nanodegree-resume',
 'firstcontributions/first-contributions',
 'freeCodeCamp/freeCodeCamp',
 'vuejs/vue',
 'getify/You-Dont-Know-JS',
 'LarryMad/recipes',
 'spring-projects/spring-framework',
 'Snailclimb/JavaGuide',
 'mrdoob/three.js',
 'd3/d3',
 'kubernetes/kubernetes',
 '996icu/996.ICU',
 'apache/spark',
 'apache/dubbo',
 'DefinitelyTyped/DefinitelyTyped',
 'django/django',
 'ant-design/ant-design',
 'shadowsocks/shadowsocks',
 'TheAlgorithms/Python',
 'justjavac/free-programming-books-zh_CN',
 'scikit-learn/scikit-learn',
 'jquery/jquery',
 'facebook/react-native',
 'ohmyzsh/ohmyzsh',
  'rails/rails',
 'slatedocs/slate',
 'BVLC/caffe',
 'git/git',
 'ansible/ansible',
 'airbnb/javascript',
 'laravel/laravel',
 'facebook/create-react-app',
 'keras-team/keras',
 'iluwatar/java-design-patterns',
 'sindresorhus/awesome',
 'moby/moby',
 'aspnet/AspNetCore.Docs',
 'PanJiaChen/vue-element-admin',
 'gabrielecirulli/2048',
 'antirez/redis',
 'nodejs/node',
 'elastic/elasticsearch',
 'angular/angular',
 'vinta/awesome-python',
 'kamranahmedse/developer-roadmap',
 'shadowsocks/shadowsocks-windows',
 'hakimel/reveal.js',
 'wakaleo/game-of-life',
 'tastejs/todomvc',
 'atom/atom',
 'reduxjs/redux',
 'daneden/animate.css',
 'aymericdamien/TensorFlow-Examples',
 'mui-org/material-ui',
 'macrozheng/mall',
 'shadowsocks/shadowsocks-android',
 'qmk/qmk_firmware',
 'protocolbuffers/protobuf',
 'electron/electron',
 'h5bp/html5-boilerplate',
 'FortAwesome/Font-Awesome',
 'bailicangdu/vue2-elm',
 'udacity/create-your-own-adventure',
 'ytdl-org/youtube-dl',
 'apache/incubator-echarts',
 'Trinea/android-open-project',
 'helm/charts',
 'udacity/fullstack-nanodegree-vm',
 'odoo/odoo',
 'selfteaching/the-craft-of-selfteaching',
 'scutan90/DeepLearning-500-questions',
 'josephmisiti/awesome-machine-learning',
 'macrozheng/mall',
 'heroku/node-js-sample',
  'shadowsocks/shadowsocks-android',
 'qmk/qmk_firmware',
 'protocolbuffers/protobuf',
 'electron/electron',
 'h5bp/html5-boilerplate',
 'FortAwesome/Font-Awesome',
 'flutter/flutter',
 'bailicangdu/vue2-elm',
 'netty/netty',
 'udacity/create-your-own-adventure',
 '/ytdl-org/youtube-dl',
 '/chartjs/Chart.js',
 '/getlantern/lantern',
 '/jenkins-docs/simple-java-maven-app',
 '/mmistakes/minimal-mistakes',
 '/AFNetworking/AFNetworking',
 '/pjreddie/darknet',
 '/android/architecture-samples',
 '/ageron/handson-ml',
 '/doocs/advanced-java',
 '/ElemeFE/element',
 '/golang/go',
 '/wasabeef/awesome-android-ui',
 '/karan/Projects',
 '/rapid7/metasploit-framework',
 '/danielmiessler/SecLists',
 '/bettiolo/node-echo',
 '/trekhleb/javascript-algorithms',
 '/astaxie/build-web-application-with-golang',
 '/ethereum/go-ethereum',
 '/pandas-dev/pandas',
 '/ityouknow/spring-boot-examples',
 '/deepfakes/faceswap',
 '/Azure/azure-quickstart-templates',
 '/PX4/Firmware',
 '/wesm/pydata-book',
 '/socketio/socket.io',
 '/jakevdp/PythonDataScienceHandbook',
 '/MicrosoftDocs/azure-docs',
 '/home-assistant/home-assistant',
 '/h5bp/Front-end-Developer-Interview-Questions',
 '/pytorch/pytorch',
 '/jekyll/jekyll',
 '/ArduPilot/ardupilot',
 '/vivienzou1/DL-Notes-for-Interview',
 '/kdn251/interviews',
 '/esp8266/Arduino',
 '/Blankj/AndroidUtilCode',
 '/scm-ninja/starter-web',
 '/233boy/v2ray',
 '/zxing/zxing',
 '/CocoaPods/Specs',
 '/ageitgey/face_recognition',
 '/MarlinFirmware/Marlin',
 '/scrapy/scrapy',
 '/kelthuzadx/hosts',
 '/hasura/imad-app',
 '/google/styleguide',
 '/google/material-design-icons',
 '/apple/swift',
     '/angular/angular-cli',
 '/blueimp/jQuery-File-Upload',
 '/WordPress/WordPress',
 '/mybatis/mybatis-3',
 '/nolimits4web/swiper',
 '/MisterBooo/LeetCodeAnimation',
 '/exacity/deeplearningbook-chinese',
 '/googlehosts/hosts',
 '/mathiasbynens/dotfiles',
 '/ReactTraining/react-router',
 '/google/guava',
 '/geekcomputers/Python',
 '/Homebrew/homebrew-cask',
 '/expressjs/express',
 '/XX-net/XX-Net',
 '/bcit-ci/CodeIgniter',
 '/spring-projects/spring-petclinic',
 '/necolas/normalize.css',
 '/nodejs/node-v0.x-archive',
 '/ruanyf/es6tutorial',
 '/PHPMailer/PHPMailer',
 '/apachecn/AiLearning',
 '/square/okhttp',
 '/leereilly/swot',
 '/microsoft/TypeScript',
 '/ossu/computer-science',
 '/jleetutorial/maven-project',
 '/apache/kafka',
 '/PhilJay/MPAndroidChart',
 '/jlevy/the-art-of-command-line',
 '/AllenDowney/ThinkStats2',
 '/public-apis/public-apis',
 '/TheAlgorithms/Java',
 '/ServiceNow/devtraining-needit-madrid',
 '/psf/requests',
 '/adam-p/markdown-here',
 '/vuejs/vuex',
 '/angular/angular-seed',
 '/ServiceNow/devtraining-needit-kingston',
 '/symfony/symfony',
 '/vuejs/awesome-vue',
 '/linuxacademy/devops-essentials-sample-app',
 '/shuzheng/zheng',
 '/shadowsocks/ShadowsocksX-NG',
 '/udacity/ud851-Exercises',
 '/swagger-api/swagger-ui',
 '/laravel/framework',
 '/matterport/Mask_RCNN',
 '/TryGhost/Ghost',
 '/ReactiveX/RxJava',
 '/vuejs/awesome-vue',
 '/linuxacademy/devops-essentials-sample-app',
 '/shuzheng/zheng',
 '/shadowsocks/ShadowsocksX-NG',
 '/udacity/ud851-Exercises',
 '/swagger-api/swagger-ui',
 '/fivethirtyeight/data',
 '/laravel/framework',
 '/matterport/Mask_RCNN',
 '/TryGhost/Ghost',
 '/ReactiveX/RxJava',
 '/daattali/beautiful-jekyll',
 '/phonegap/phonegap-start',
 '/julycoding/The-Art-Of-Programming-By-July',
 '/impress/impress.js',
 '/yiisoft/yii2',
 '/mozilla/pdf.js',
 '/kallaway/100-days-of-code',
 '/cocos2d/cocos2d-x',
 '/gatsbyjs/gatsby',
 '/chanjarster/weixin-java-tools',
 '/Avik-Jain/100-Days-Of-ML-Code',
 '/lib-pku/libpku',
 '/alvarotrigo/fullPage.js',
 '/lewagon/dotfiles',
 '/learn-co-students/python-practice-with-datatypes-data-science-intro-000',
 '/ctripcorp/apollo',
 '/alibaba/druid',
 '/webpack/webpack',
 '/discourse/discourse',
 '/avelino/awesome-go',
 '/bilibili/ijkplayer',
 '/arduino/Arduino',
 '/adobe/brackets',
 '/prakhar1989/awesome-courses',
 '/deadlyvipers/dojo_rules',
 '/learn-co-students/js-functions-lab-bootcamp-prep-000',
 '/academicpages/academicpages.github.io',
 '/crossoverJie/JCSprout',
 '/apache/incubator-mxnet',
 '/moment/moment',
 '/abhat222/Data-Science--Cheat-Sheet',
 '/learn-co-students/js-if-else-files-lab-bootcamp-prep-000',
 '/amjuarez/bytecoin',
 '/dcloudio/mui',
 '/thebigsmileXD/PocketMine-0.13.0',
 '/awesomedata/awesome-public-datasets',
 '/square/retrofit',
 '/learn-co-students/first-ide-lab-bootcamp-prep-000',
 '/grafana/grafana']

len(repos)
# Out:
# 260

# %%
get_urls(1,5)
# Out:
# ['/jtleek/datasharing',
#  '/rdpeng/ProgrammingAssignment2',
#  '/octocat/Spoon-Knife',
#  '/tensorflow/tensorflow',
#  '/twbs/bootstrap',
#  '/SmartThingsCommunity/SmartThingsPublic',
#  '/rdpeng/ExData_Plotting1',
#  '/github/gitignore',
#  '/tensorflow/models',
#  '/nightscout/cgm-remote-monitor',
#  '/EbookFoundation/free-programming-books',
#  '/rdpeng/RepData_PeerAssessment1',
#  '/opencv/opencv',
#  '/torvalds/linux',
#  '/angular/angular.js',
#  '/eugenp/tutorials',
#  '/DataScienceSpecialization/courses',
#  '/jackfrued/Python-100-Days',
#  '/spring-projects/spring-boot',
#  '/jwasham/coding-interview-university',
#  '/CyC2018/CS-Notes',
#  '/facebook/react',
#  '/barryclark/jekyll-now',
#  '/jlord/patchwork',
#  '/Pierian-Data/Complete-Python-3-Bootcamp',
#  '/bitcoin/bitcoin',
#  '/udacity/frontend-nanodegree-resume',
#  '/firstcontributions/first-contributions',
#  '/freeCodeCamp/freeCodeCamp',
#  '/vuejs/vue',
#  '/getify/You-Dont-Know-JS',
#  '/LarryMad/recipes',
# ...

# %%
second_set = get_urls(6,10)
# Out:
# ['/rails/rails',
#  '/slatedocs/slate',
#  '/BVLC/caffe',
#  '/git/git',
#  '/ansible/ansible',
#  '/airbnb/javascript',
#  '/laravel/laravel',
#  '/facebook/create-react-app',
#  '/keras-team/keras',
#  '/iluwatar/java-design-patterns',
#  '/sindresorhus/awesome',
#  '/moby/moby',
#  '/aspnet/AspNetCore.Docs',
#  '/PanJiaChen/vue-element-admin',
#  '/gabrielecirulli/2048',
#  '/antirez/redis',
#  '/nodejs/node',
#  '/elastic/elasticsearch',
#  '/angular/angular',
#  '/vinta/awesome-python',
#  '/kamranahmedse/developer-roadmap',
#  '/shadowsocks/shadowsocks-windows',
#  '/hakimel/reveal.js',
#  '/wakaleo/game-of-life',
#  '/tastejs/todomvc',
#  '/atom/atom',
#  '/reduxjs/redux',
#  '/daneden/animate.css',
#  '/aymericdamien/TensorFlow-Examples',
#  '/mui-org/material-ui',
#  '/macrozheng/mall',
#  '/shadowsocks/shadowsocks-android',
#  '/qmk/qmk_firmware',
#  '/protocolbuffers/protobuf',
#  '/electron/electron',
#  '/h5bp/html5-boilerplate',
#  '/FortAwesome/Font-Awesome',
# ...

# %%
get_urls(11,16)
# Out:
# ['/shadowsocks/shadowsocks-android',
#  '/qmk/qmk_firmware',
#  '/protocolbuffers/protobuf',
#  '/electron/electron',
#  '/h5bp/html5-boilerplate',
#  '/FortAwesome/Font-Awesome',
#  '/flutter/flutter',
#  '/bailicangdu/vue2-elm',
#  '/netty/netty',
#  '/udacity/create-your-own-adventure',
#  '/ytdl-org/youtube-dl',
#  '/chartjs/Chart.js',
#  '/getlantern/lantern',
#  '/jenkins-docs/simple-java-maven-app',
#  '/mmistakes/minimal-mistakes',
#  '/AFNetworking/AFNetworking',
#  '/pjreddie/darknet',
#  '/android/architecture-samples',
#  '/ageron/handson-ml',
#  '/doocs/advanced-java',
#  '/ElemeFE/element',
#  '/golang/go',
#  '/wasabeef/awesome-android-ui',
#  '/karan/Projects',
#  '/rapid7/metasploit-framework',
#  '/danielmiessler/SecLists',
#  '/bettiolo/node-echo',
#  '/trekhleb/javascript-algorithms',
#  '/astaxie/build-web-application-with-golang',
#  '/ethereum/go-ethereum',
#  '/pandas-dev/pandas',
#  '/ityouknow/spring-boot-examples',
#  '/deepfakes/faceswap',
# ...

# %%
get_urls(17,21)
# Out:
# ['/angular/angular-cli',
#  '/blueimp/jQuery-File-Upload',
#  '/WordPress/WordPress',
#  '/mybatis/mybatis-3',
#  '/nolimits4web/swiper',
#  '/MisterBooo/LeetCodeAnimation',
#  '/exacity/deeplearningbook-chinese',
#  '/googlehosts/hosts',
#  '/mathiasbynens/dotfiles',
#  '/ReactTraining/react-router',
#  '/google/guava',
#  '/geekcomputers/Python',
#  '/Homebrew/homebrew-cask',
#  '/expressjs/express',
#  '/XX-net/XX-Net',
#  '/bcit-ci/CodeIgniter',
#  '/spring-projects/spring-petclinic',
#  '/necolas/normalize.css',
#  '/nodejs/node-v0.x-archive',
#  '/ruanyf/es6tutorial',
#  '/PHPMailer/PHPMailer',
#  '/apachecn/AiLearning',
#  '/square/okhttp',
#  '/leereilly/swot',
#  '/microsoft/TypeScript',
#  '/ossu/computer-science',
#  '/jleetutorial/maven-project',
#  '/apache/kafka',
#  '/PhilJay/MPAndroidChart',
#  '/jlevy/the-art-of-command-line',
#  '/AllenDowney/ThinkStats2',
#  '/public-apis/public-apis',
#  '/TheAlgorithms/Java',
#  '/ServiceNow/devtraining-needit-madrid',
# ...

# %%
get_urls(22,26)
# Out:
# ['/vuejs/awesome-vue',
#  '/linuxacademy/devops-essentials-sample-app',
#  '/shuzheng/zheng',
#  '/shadowsocks/ShadowsocksX-NG',
#  '/udacity/ud851-Exercises',
#  '/swagger-api/swagger-ui',
#  '/fivethirtyeight/data',
#  '/laravel/framework',
#  '/matterport/Mask_RCNN',
#  '/TryGhost/Ghost',
#  '/ReactiveX/RxJava',
#  '/daattali/beautiful-jekyll',
#  '/phonegap/phonegap-start',
#  '/julycoding/The-Art-Of-Programming-By-July',
#  '/impress/impress.js',
#  '/yiisoft/yii2',
#  '/mozilla/pdf.js',
#  '/kallaway/100-days-of-code',
#  '/cocos2d/cocos2d-x',
#  '/gatsbyjs/gatsby',
#  '/chanjarster/weixin-java-tools',
#  '/Avik-Jain/100-Days-Of-ML-Code',
#  '/lib-pku/libpku',
#  '/alvarotrigo/fullPage.js',
#  '/lewagon/dotfiles',
#  '/learn-co-students/python-practice-with-datatypes-data-science-intro-000',
#  '/ctripcorp/apollo',
#  '/alibaba/druid',
#  '/webpack/webpack',
#  '/discourse/discourse',
#  '/avelino/awesome-go',
#  '/bilibili/ijkplayer',
#  '/arduino/Arduino',
# ...
