# %%
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

# %%
def get_news_articles():
    filename = 'inshorts_news_articles.csv'

    # check for presence of the file or make a new request
    if os.path.exists(filename):
        return pd.read_csv(filename)
    else:
        return make_new_request()

# %%
def get_articles_from_topic(url):
    headers = {'user-agent': 'Codeup Bayes Instructor Example'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    output = []

    articles = soup.select(".news-card")

    for article in articles: 
        title = article.select("[itemprop='headline']")[0].get_text()
        content = article.select("[itemprop='articleBody']")[0].get_text()
        author = article.select(".author")[0].get_text()
        published_date = article.select(".time")[0]["content"]
        category = response.url.split("/")[-1]

        article_data = {
            'title': title,
            'content': content,
            'category': category,
            'author': author,
            'published_date': published_date,
        }
        output.append(article_data)


    return output

# %%
def make_new_request():
    urls = [
        "https://inshorts.com/en/read/business",
        "https://inshorts.com/en/read/sports",
        "https://inshorts.com/en/read/technology",
        "https://inshorts.com/en/read/entertainment"
    ]

    output = []
    
    for url in urls:
        # We use .extend in order to make a flat output list.
        output.extend(get_articles_from_topic(url))

    print("stuff")
    print(output)
    df = pd.DataFrame(output)
    df.to_csv('inshorts_news_articles.csv') 

    return df

# %%
make_new_request()
# Out:
# stuff
# [{'title': 'Ex-Infosys CEO Vishal Sikka joins Oracle board after launching AI startup', 'content': 'Former Infosys CEO Vishal Sikka, who launched his AI startup Vianai Systems in September, has been named to Oracle\'s board of directors. Before joining Infosys as its first non-founder CEO in 2014, Sikka worked at German software company SAP. "Vishal is one the world\'s leading experts in Artificial Intelligence and Machine Learning," Oracle Co-Founder, Chairman and CTO Larry Ellison said.', 'category': 'business', 'author': 'Krishna Veera Vanamali', 'published_date': '2019-12-10T11:43:31.000Z'}, {'title': 'Sundar Pichai-led Alphabet adds Nobel laureate Frances Arnold to board', 'content': 'Google and its parent organisation Alphabet\'s CEO Sundar Pichai took to Twitter to welcome 2018 Chemistry Nobel Prize winner Frances Arnold to the parent entity\'s board. "Frances brings incredible academic and industry expertise with a career spanning chemistry, engineering, renewable energy and more," tweeted Pichai. Arnold won the Nobel "for the directed evolution of enzymes".', 'category': 'business', 'author': 'Kanishka Pandey', 'published_date': '2019-12-10T03:28:37.000Z'}, {'title': 'Trump interfered with $10 bn JEDI contract to harm CEO Bezos: Amazon', 'content': 'Jeff Bezos-led Amazon filed a complaint accusing US President Donald Trump of exerting "improper pressure" and bias over Pentagon\'s $10-billion JEDI defence contract. Trump "launched repeated public and behind-the-scenes attacks to steer JEDI Contract away from [Amazon] to harm his perceived political enemy-Jeffrey P Bezos," alleged Amazon. The e-commerce giant had lost the contract to Microsoft.', 'category': 'business', 'author': 'Kanishka Pandey', 'published_date': '2019-12-10T04:25:57.000Z'}, {'title': "Mahindra credits Gulzar for shayari on mobile, people say it's not by the poet", 'content': "Mahindra Group Chairman Anand Mahindra on Monday took to Twitter to share a shayari (couplet) revolving around mobile phones and credited poet Gulzar for penning it down. However, several users pointed out that Gulzar was not behind the couplet. A user also posted a screengrab showing the couplet on Facebook Page 'NotByGulzar' that documents poetry wrongly cred
# 2   Trump interfered with $10 bn JEDI contract to ...
# 3   Mahindra credits Gulzar for shayari on mobile,...
# 4   Tariff hikes can double telcos' operating prof...
# 5   Who are India's richest real estate tycoons ac...
# 6   Corporate tax cuts not sufficient to attract i...
# 7   I'm Canada's richest man, Netflix and Amazon w...
# 8   I wanted to buy a proper piano until I saw the...
# 9   Walmart apologises for sweaters showing Santa ...
# 10  If Yes Bank was called 'No Bank', I wouldn't h...
# 11  Passenger vehicle sales fall marginally by 1% ...
# 12  India moves one spot up, ranks 129 in UN's Hum...
# 13  SBI reduces lending rate by 10 bps in 8th cons...
# 14  Aramco IPO proceeds rise to $29.4 bn after sel...
# 15  Paul Volcker, former Fed Chairman who curbed i...
# 16  Yes Bank stalls sale of Coffee Day's tech park...
# 17  Executives at state-run firms oppose privatisa...
# 18  Companies may get 2 years to comply with data ...
# 19  SBI under-reported bad loans by ₹11,932 crore ...
# 20  Morgan Stanley to cut about 1,500 jobs globall...
# 21  SBI under-reported bad loans by ₹11,932 crore ...
# 22  Morgan Stanley fined $22 million for bond pric...
# 23  Yes Bank may reject $1.2 billion bid from Cana...
# 24  Tata Steel to give HR benefits to partners of ...
# 25  Azharuddin, Sania invite Telangana CM for Asad...
# 26  Bowler opts not to run out injured batsman, ge...
# 27  Hoped India would've rested someone to allow S...
# 28  Kohli's 'Dhoni always my captain' most retweet...
# 29  MS Dhoni is a legend, won't impose himself on ...
# ..                                                ...
# 70  PM Modi visits supercomputer facility in Pune,...
# 71  Apple's upcoming iPhone SE 2 may be named 'iPh...
# 72  Twitter reveals top tweets of 2019, says viral...
# 73  Apple may launch as many as six iPhones in 202...
# 74  ISRO to launch 2nd spy satellite on Dec 11 to ...
# 75  1st picture of Lata after spending 28 days in ...
# 76  SRK holds train of wife Gauri's gown at award ...
# 77  Deepika cries at trailer launch of Chhapaak wh...
# 78  Shouldn't say 'darr lagta hai': Deepika to rep...
# 79  Trailer of Deepika's Chhapaak, where she plays...
# 80  Went to houses on Diwali, told not to burst cr...
# 81  Jolie meets 22-yr-old actor who has tattoo of ...
# 82  Makdee actress Shweta announces separation fro...
# 83  Sonakshi, Big B top 2019's most tweeted handle...
# 84  Ayushmann to star in Hindi remake of Tamil fil...
# 85  It's scary, exciting: Soha on watching 2-yr-ol...
# 86  It's going to be challenging for me: Taapsee o...
# 87  Jaipur theatres stop screening 'Panipat' after...
# 88  I'm not drawn towards a sexist or gender-biase...
# 89  Some people say I look better now: Jennifer Lo...
# 90  Who are the Best Actress nominees at Golden Gl...
# 91  Want a society where men stand with women: Esh...
# 92  I've never been drunk in my entire life: Actre...
# 93  It was all a dream: Ranveer on 9 yrs of debut ...
# 94  Suniel Shetty to be made NADA's anti-doping br...
# 95  24-year-old Noida singer does Hindi playback i...
# 96  Deepika left her glamorous side behind for Chh...
# 97  Maybe we'll get the Oscar this time: Gully Boy...
# 98  Deepika, Meghna will earn a lot of tears from ...
# 99  Deeply ashamed: Siddharth on Tamil Nadu CM sup...
#
# [100 rows x 5 columns]
